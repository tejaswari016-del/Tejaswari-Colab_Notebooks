# %%
#Step 1: Import Libraries
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.naive_bayes import CategoricalNB

#Step 2: Create dataset
data = {
    'Weather': ['Sunny','Sunny','Rainy','Rainy','Cloudy','Sunny','Cloudy','Rainy'],
    'Soil': ['Dry','Wet','Wet','Dry','Dry','Dry','Wet','Wet'],
    'Temperature': ['Hot','Hot','Cool','Cool','Cool','Cool','Hot','Hot'],
    'Irrigate': ['Yes','No','No','Yes','Yes','Yes','No','No']
}
df = pd.DataFrame(data)

print("Dataset:\n",df)

#Step 3: Encode categorical features
le_weather = LabelEncoder()
le_soil = LabelEncoder()
le_temp = LabelEncoder()
le_target = LabelEncoder()

df['Weather'] = le_weather.fit_transform(df['Weather'])
df['Soil'] = le_soil.fit_transform(df['Soil'])
df['Temperature'] = le_temp.fit_transform(df['Temperature'])
df['Irrigate'] = le_target.fit_transform(df['Irrigate'])

print("\nEncoded Dataset:\n",df)

#Step 4: Split Features and Target
X = df[['Weather','Soil','Temperature']]
y = df['Irrigate']

#Step 5: Train Naive Bayes Model
model = CategoricalNB()
model.fit(X,y)

#Step 6 : Test Input(Sunny,Dry,cool)
test_data = pd.DataFrame({
    'Weather':['Sunny'],
    'Soil':['Dry'],
    'Temperature':['Cool']
})

#Encode test data using same encoders
test_data['Weather'] = le_weather.transform(test_data['Weather'])
test_data['Soil'] = le_soil.transform(test_data['Soil'])
test_data['Temperature'] = le_temp.transform(test_data['Temperature'])

#Step 7 : Prediction
prediction = model.predict(test_data)

#Convert back to original label
result = le_target.inverse_transform(prediction)

print("\nTest Input: Sunny,Dry,Cool")
print("Prediction:",result[0])

#Step 8: Probability output(optional)
prob = model.predict_proba(test_data)
print("Class Probabilities:",prob)
# Out:
# Dataset:
#    Weather Soil Temperature Irrigate
# 0   Sunny  Dry         Hot      Yes
# 1   Sunny  Wet         Hot       No
# 2   Rainy  Wet        Cool       No
# 3   Rainy  Dry        Cool      Yes
# 4  Cloudy  Dry        Cool      Yes
# 5   Sunny  Dry        Cool      Yes
# 6  Cloudy  Wet         Hot       No
# 7   Rainy  Wet         Hot       No
#
# Encoded Dataset:
#     Weather  Soil  Temperature  Irrigate
# 0        2     0            1         1
# 1        2     1            1         0
# 2        1     1            0         0
# 3        1     0            0         1
# 4        0     0            0         1
# 5        2     0            0         1
# 6        0     1            1         0
# 7        1     1            1         0
#
# Test Input: Sunny,Dry,Cool
# Prediction: Yes
# Class Probabilities: [[0.0625 0.9375]]

# %%
#Step 1: Import Libraries
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.naive_bayes import CategoricalNB

#Step 2: Create dataset
data = {
    'Weather': ['Sunny','Sunny','Rainy','Rainy','Cloudy','Sunny','Cloudy','Rainy'],
    'Soil': ['Dry','Wet','Wet','Dry','Dry','Dry','Wet','Wet'],
    'Temperature': ['Hot','Hot','Cool','Cool','Cool','Cool','Hot','Hot'],
    'Irrigate': ['Yes','No','No','Yes','Yes','Yes','No','No']
}
df = pd.DataFrame(data)

print("Dataset:\n",df)

#Step 3: Encode categorical features
le_weather = LabelEncoder()
le_soil = LabelEncoder()
le_temp = LabelEncoder()
le_target = LabelEncoder()

df['Weather'] = le_weather.fit_transform(df['Weather'])
df['Soil'] = le_soil.fit_transform(df['Soil'])
df['Temperature'] = le_temp.fit_transform(df['Temperature'])
df['Irrigate'] = le_target.fit_transform(df['Irrigate'])

print("\nEncoded Dataset:\n",df)

#Step 4: Split Features and Target
X = df[['Weather','Soil','Temperature']]
y = df['Irrigate']

#Step 5: Train Naive Bayes Model
model = CategoricalNB()
model.fit(X,y)

#Step 6 : Test Input(Sunny,Dry,cool)
test_data = pd.DataFrame({
    'Weather':['Cloudy'],
    'Soil':['Wet'],
    'Temperature':['Hot']
})

#Encode test data using same encoders
test_data['Weather'] = le_weather.transform(test_data['Weather'])
test_data['Soil'] = le_soil.transform(test_data['Soil'])
test_data['Temperature'] = le_temp.transform(test_data['Temperature'])

#Step 7 : Prediction
prediction = model.predict(test_data)

#Convert back to original label
result = le_target.inverse_transform(prediction)

print("\nTest Input: Cloudy,Wet,Hot")
print("Prediction:",result[0])

#Step 8: Probability output(optional)
prob = model.predict_proba(test_data)
print("Class Probabilities:",prob)
# Out:
# Dataset:
#    Weather Soil Temperature Irrigate
# 0   Sunny  Dry         Hot      Yes
# 1   Sunny  Wet         Hot       No
# 2   Rainy  Wet        Cool       No
# 3   Rainy  Dry        Cool      Yes
# 4  Cloudy  Dry        Cool      Yes
# 5   Sunny  Dry        Cool      Yes
# 6  Cloudy  Wet         Hot       No
# 7   Rainy  Wet         Hot       No
#
# Encoded Dataset:
#     Weather  Soil  Temperature  Irrigate
# 0        2     0            1         1
# 1        2     1            1         0
# 2        1     1            0         0
# 3        1     0            0         1
# 4        0     0            0         1
# 5        2     0            0         1
# 6        0     1            1         0
# 7        1     1            1         0
#
# Test Input: Cloudy,Wet,Hot
# Prediction: No
# Class Probabilities: [[0.90909091 0.09090909]]

# %%
#Step 1: Import Libraries
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.naive_bayes import CategoricalNB

#Step 2: Create dataset
data = {
    'Weather': ['Sunny','Sunny','Rainy','Rainy','Cloudy','Sunny','Cloudy','Rainy'],
    'Soil': ['Dry','Wet','Wet','Dry','Dry','Dry','Wet','Wet'],
    'Temperature': ['Hot','Hot','Cool','Cool','Cool','Cool','Hot','Hot'],
    'Irrigate': ['Yes','No','No','Yes','Yes','Yes','No','No']
}
df = pd.DataFrame(data)

print("Dataset:\n",df)

#Step 3: Encode categorical features
le_weather = LabelEncoder()
le_soil = LabelEncoder()
le_temp = LabelEncoder()
le_target = LabelEncoder()

df['Weather'] = le_weather.fit_transform(df['Weather'])
df['Soil'] = le_soil.fit_transform(df['Soil'])
df['Temperature'] = le_temp.fit_transform(df['Temperature'])
df['Irrigate'] = le_target.fit_transform(df['Irrigate'])

print("\nEncoded Dataset:\n",df)

#Step 4: Split Features and Target
X = df[['Weather','Soil','Temperature']]
y = df['Irrigate']

#Step 5: Train Naive Bayes Model
model = CategoricalNB()
model.fit(X,y)

#Step 6 : Test Input(Sunny,Dry,cool)
test_data = pd.DataFrame({
    'Weather':['Rainy'],
    'Soil':['Wet'],
    'Temperature':['Hot']
})

#Encode test data using same encoders
test_data['Weather'] = le_weather.transform(test_data['Weather'])
test_data['Soil'] = le_soil.transform(test_data['Soil'])
test_data['Temperature'] = le_temp.transform(test_data['Temperature'])

#Step 7 : Prediction
prediction = model.predict(test_data)

#Convert back to original label
result = le_target.inverse_transform(prediction)

print("\nTest Input: Rainy,Wet,Hot")
print("Prediction:",result[0])

#Step 8: Probability output(optional)
prob = model.predict_proba(test_data)
print("Class Probabilities:",prob)
# Out:
# Dataset:
#    Weather Soil Temperature Irrigate
# 0   Sunny  Dry         Hot      Yes
# 1   Sunny  Wet         Hot       No
# 2   Rainy  Wet        Cool       No
# 3   Rainy  Dry        Cool      Yes
# 4  Cloudy  Dry        Cool      Yes
# 5   Sunny  Dry        Cool      Yes
# 6  Cloudy  Wet         Hot       No
# 7   Rainy  Wet         Hot       No
#
# Encoded Dataset:
#     Weather  Soil  Temperature  Irrigate
# 0        2     0            1         1
# 1        2     1            1         0
# 2        1     1            0         0
# 3        1     0            0         1
# 4        0     0            0         1
# 5        2     0            0         1
# 6        0     1            1         0
# 7        1     1            1         0
#
# Test Input: Rainy,Wet,Hot
# Prediction: No
# Class Probabilities: [[0.9375 0.0625]]

# %%
#Step 1: Import Libraries
import pandas as pd
from sklearn.preprocessing import LabelEncoder
from sklearn.naive_bayes import CategoricalNB

#Step 2: Create dataset
data = {
    'Weather': ['Sunny','Sunny','Rainy','Rainy','Cloudy','Cloudy','Sunny','Rainy'],
    'Humidity': ['High','Low','High','High','Low','High','High','Low'],
    'Crop Stage': ['Flowering','Vegetative','Flowering','Vegetative','Vegetative','Flowering','Vegetative','Flowering'],
    'Pest Attack': ['Yes','No','Yes','Yes','No','Yes','No','No']
}
df = pd.DataFrame(data)

print("Dataset:\n",df)

#Step 3: Encode categorical features
le_weather = LabelEncoder()
le_humid = LabelEncoder()
le_cropstg = LabelEncoder()
le_target = LabelEncoder()

df['Weather'] = le_weather.fit_transform(df['Weather'])
df['Humidity'] = le_humid.fit_transform(df['Humidity'])
df['Crop Stage'] = le_cropstg.fit_transform(df['Crop Stage'])
df['Pest Attack'] = le_target.fit_transform(df['Pest Attack']) # Corrected 'Pest Attack' to 'Pest attack'

print("\nEncoded Dataset:\n",df)

#Step 4: Split Features and Target
X = df[['Weather','Humidity','Crop Stage']]
y = df['Pest Attack'] # Corrected 'Pest Attack' to 'Pest attack'

#Step 5: Train Naive Bayes Model
model = CategoricalNB()
model.fit(X,y)

#Step 6 : Test Input(Sunny,Dry,cool)
test_data = pd.DataFrame({
    'Weather':['Sunny'],
    'Humidity':['High'],
    'Crop Stage':['Vegetative']
})

#Encode test data using same encoders
test_data['Weather'] = le_weather.transform(test_data['Weather'])
test_data['Humidity'] = le_humid.transform(test_data['Humidity'])
test_data['Crop Stage'] = le_cropstg.transform(test_data['Crop Stage'])

#Step 7 : Prediction
prediction = model.predict(test_data)

#Convert back to original label
result = le_target.inverse_transform(prediction)

print("\nTest Input: Sunny,High,Vegetative")
print("Prediction:",result[0])

#Step 8: Probability output(optional)
prob = model.predict_proba(test_data)
print("Class Probabilities:",prob)
# Out:
# Dataset:
#    Weather Humidity  Crop Stage Pest Attack
# 0   Sunny     High   Flowering         Yes
# 1   Sunny      Low  Vegetative          No
# 2   Rainy     High   Flowering         Yes
# 3   Rainy     High  Vegetative         Yes
# 4  Cloudy      Low  Vegetative          No
# 5  Cloudy     High   Flowering         Yes
# 6   Sunny     High  Vegetative          No
# 7   Rainy      Low   Flowering          No
#
# Encoded Dataset:
#     Weather  Humidity  Crop Stage  Pest Attack
# 0        2         0           0            1
# 1        2         1           1            0
# 2        1         0           0            1
# 3        1         0           1            1
# 4        0         1           1            0
# 5        0         0           0            1
# 6        2         0           1            0
# 7        1         1           0            0
#
# Test Input: Sunny,High,Vegetative
# Prediction: No
# Class Probabilities: [[0.54545455 0.45454545]]
