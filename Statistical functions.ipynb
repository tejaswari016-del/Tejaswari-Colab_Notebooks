# %%
import numpy as np  #rainfall data(mm) over 12 months
rainfall = np.array([45,52,68,120,180,220,195,160,110,75,58,40])

#Corresponding crop yield(tons/hectare)
yields = np.array([2.1,2.3,2.8,4.2,5.8,6.5,5.9,5.2,3.8,2.9,2.4,2.0])

print('========RAINFALL STATISTICS=========')
print(f'Mean: {np.mean(rainfall):.2f}mm')
print(f'Median:{np.median(rainfall):2f}mm')
print(f'Std dev:{np.std(rainfall):2f}mm')
print(f'Variance:{np.var(rainfall):.2f}mm')
print(f'Min:{np.min(rainfall)}mm(Month{np.argmin(rainfall)+1})')
print(f'Max:{np.max(rainfall)}mm(Month{np.argmax(rainfall)+1})')
print(f'Range:{np.ptp(rainfall)}mm')

print('\n========YIELD STATISTICS========')
print(f'Mean:{np.mean(yields):.2f}tons/ha')
print(f'Median:{np.median(yields):.2f}tons/ha')
print(f'Std dev:{np.std(yields):.2f}tons/ha')

print('\n=========CORRELATION ANALYSIS=========')
correlation_matrix = np.corrcoef(rainfall,yields)
correlation = correlation_matrix[0,1]
print(f'Rainfall-Yield correlation: {correlation:.4f}')
print('Interpretation:Strong positive correlation' if correlation>0.7 else 'Moderate correlation' if correlation>0.4 else 'Weak correlation')

print('================CUMULATIVE RAINFALL================')
cumulative = np.cumsum(rainfall)
print('Month \t Rainfall \t Cumulative')
for month,(rain,cum) in enumerate (zip(rainfall,cumulative),1):
  print(f'{month} \t {rain} \t\t {cum}')
# Out:
# ========RAINFALL STATISTICS=========
# Mean: 110.25mm
# Median:92.500000mm
# Std dev:61.241496mm
# Variance:3750.52mm
# Min:40mm(Month12)
# Max:220mm(Month6)
# Range:180mm
#
# ========YIELD STATISTICS========
# Mean:3.82tons/ha
# Median:3.35tons/ha
# Std dev:1.58tons/ha
#
# =========CORRELATION ANALYSIS=========
# Rainfall-Yield correlation: 0.9983
# Interpretation:Strong positive correlation
# ================CUMULATIVE RAINFALL================
# Month 	 Rainfall 	 Cumulative
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# /tmp/ipython-input-2909612287.py in <cell line: 0>()
#      28 cumulative = np.cumsum(rainfall)
#      29 print('Month \t Rainfall \t Cumulative')
# ---> 30 for month,(rain,cum) in enumerate ((rainfall,cumulative),1):
#      31   print(f'{month} \t {rain} \t\t {cum}')
#
# ValueError: too many values to unpack (expected 2)

# %%
import numpy as np  #rainfall data(mm) over 12 months
import matplotlib.pyplot as plt
rainfall = np.array([45,52,68,120,180,220,195,160,110,75,58,40])

#Corresponding crop yield(tons/hectare)
yields = np.array([2.1,2.3,2.8,4.2,5.8,6.5,5.9,5.2,3.8,2.9,2.4,2.0])

print('========RAINFALL STATISTICS=========')
print(f'Mean: {np.mean(rainfall):.2f}mm')
print(f'Median:{np.median(rainfall):2f}mm')
print(f'Std dev:{np.std(rainfall):2f}mm')
print(f'Variance:{np.var(rainfall):.2f}mm')
print(f'Min:{np.min(rainfall)}mm(Month{np.argmin(rainfall)+1})')
print(f'Max:{np.max(rainfall)}mm(Month{np.argmax(rainfall)+1})')
print(f'Range:{np.ptp(rainfall)}mm')

print('\n========YIELD STATISTICS========')
print(f'Mean:{np.mean(yields):.2f}tons/ha')
print(f'Median:{np.median(yields):.2f}tons/ha')
print(f'Std dev:{np.std(yields):.2f}tons/ha')

print('\n=========CORRELATION ANALYSIS=========')
correlation_matrix = np.corrcoef(rainfall,yields)
correlation = correlation_matrix[0,1]
print(f'Rainfall-Yield correlation: {correlation:.4f}')
print('Interpretation:Strong positive correlation' if correlation>0.7 else 'Moderate correlation' if correlation>0.4 else 'Weak correlation')

print('================CUMULATIVE RAINFALL================')
cumulative = np.cumsum(rainfall)
print('Month \t Rainfall \t Cumulative')
for month,(rain,cum) in enumerate (zip(rainfall,cumulative),1):
  print(f'{month} \t {rain} \t\t {cum}')

x_coords = np.array([45,52,68,120,180,220,195,160,110,75,58,40])
y_coords = np.array([2.1,2.3,2.8,4.2,5.8,6.5,5.9,5.2,3.8,2.9,2.4,2.0])

plt.plot(x_coords,y_coords)
plt.xlabel("rainfall data(mm)")
plt.ylabel("yields(tons/hectare)")
plt.title("Rainfall vs Crop yield")
plt.xticks(months)
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.legend()
plt.show()

plt.bar(months, rainfall, color='skyblue')
plt.title('Monthly Rainfall')
plt.xlabel('Month')
plt.ylabel('Rainfall (mm)')
plt.show()
# Out:
# ========RAINFALL STATISTICS=========
# Mean: 110.25mm
# Median:92.500000mm
# Std dev:61.241496mm
# Variance:3750.52mm
# Min:40mm(Month12)
# Max:220mm(Month6)
# Range:180mm
#
# ========YIELD STATISTICS========
# Mean:3.82tons/ha
# Median:3.35tons/ha
# Std dev:1.58tons/ha
#
# =========CORRELATION ANALYSIS=========
# Rainfall-Yield correlation: 0.9983
# Interpretation:Strong positive correlation
# ================CUMULATIVE RAINFALL================
# Month 	 Rainfall 	 Cumulative
# 1 	 45 		 45
# 2 	 52 		 97
# 3 	 68 		 165
# 4 	 120 		 285
# 5 	 180 		 465
# 6 	 220 		 685
# 7 	 195 		 880
# 8 	 160 		 1040
# 9 	 110 		 1150
# 10 	 75 		 1225
# 11 	 58 		 1283
# 12 	 40 		 1323
# /tmp/ipython-input-1144931827.py:43: UserWarning: No artists with labels found to put in legend.  Note that artists whose label start with an underscore are ignored when legend() is called with no argument.
#   plt.legend()

# %%
import matplotlib.pyplot as plt

# Months
months = np.arange(1, 13)

# ---------------- Line Graph: Rainfall ---------------- #
plt.figure(figsize=(10,5))
plt.plot(months, rainfall, marker='o', color='blue', label='Rainfall (mm)')
plt.plot(months, cumulative, marker='x', linestyle='--', color='cyan', label='Cumulative Rainfall (mm)')
plt.title('Monthly Rainfall and Cumulative Rainfall')
plt.xlabel('Month')
plt.ylabel('Rainfall (mm)')
plt.xticks(months)
plt.grid(True, linestyle='--', alpha=0.5)
plt.legend()
plt.show()

# ---------------- Line Graph: Crop Yield ---------------- #
plt.figure(figsize=(10,5))
plt.plot(months, yields, marker='s', color='green', label='Crop Yield (tons/ha)')
plt.title('Monthly Crop Yield')
plt.xlabel('Month')
plt.ylabel('Yield (tons/ha)')
plt.xticks(months)
plt.grid(True, linestyle='--', alpha=0.5)
plt.legend()
plt.show()

# ---------------- Scatter Plot: Rainfall vs Yield ---------------- #
plt.figure(figsize=(8,6))
plt.scatter(rainfall, yields, color='orange', s=80)
for i in range(len(months)):
    plt.text(rainfall[i]+2, yields[i], f'M{i+1}')
plt.title('Rainfall vs Crop Yield')
plt.xlabel('Rainfall (mm)')
plt.ylabel('Yield (tons/ha)')
plt.grid(True, linestyle='--', alpha=0.5)
plt.show()

# ---------------- Bar Graph: Monthly Rainfall ---------------- #
plt.figure(figsize=(10,5))
plt.bar(months, rainfall, color='skyblue')
plt.title('Monthly Rainfall')
plt.xlabel('Month')
plt.ylabel('Rainfall (mm)')
plt.xticks(months)
plt.grid(axis='y', linestyle='--', alpha=0.5)
plt.show()
