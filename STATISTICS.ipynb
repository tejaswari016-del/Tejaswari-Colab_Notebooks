# %%
#Calculating student examination marks
import numpy as np

n = int(input("Enter number of students: "))
s = int(input("Enter number of subjects: "))
subjects = []
print("\nEnter subject names: ")
for i in range(s):
    sub = input(f"Subject {i+1}: ")
    subjects.append(sub)
all_marks = []

print("\nEnter marks for each student: ")
for i in range(n):
   print(f"\nStudent {i+1}: ")
   student_marks = []
   for j in range(s):
       mark = float(input(f"{subjects[j]}: "))
       student_marks.append(mark)
   all_marks.append(student_marks)

marks = np.array(all_marks)

#==================STUDENT-WISE ANALYSIS==================
print("\n===== STUDENT-WISE ANALYSIS =====")
for i in range(n):
   total = np.sum(marks[i])
   average = np.mean(marks[i])
   print(f"Student {i+1} ---> Total: {total:.2f}, Average: {average:.2f}")

#=================SUBJECT WISE ANALYSIS====================
print("\n==== SUBJECT-WISE ANALYSIS ====")
for j in range(s):
    print(f"\nSubject: {subjects[j]}")
    print(f"Average marks: {np.mean(marks[:,j]):.2f}")
    print(f"Highest marks: {np.max(marks[:,j])}")
    print(f"Lowest marks: {np.min(marks[:,j])}")

total_marks = np.sum(marks,axis=1)
topper = np.argmax(total_marks)+1

print("=======OVERALL TOPPER=======")
print(f"Topper of the examination: Student{topper}")
# Out:
# Enter number of students: 3
# Enter number of subjects: 4
#
# Enter subject names:
# Subject 1: Maths
# Subject 2: Social
# Subject 3: Computer science
# Subject 4: Hindi
#
# Enter marks for each student:
#
# Student 1:
# Maths: 95
# Social: 98
# Computer science: 89
# Hindi: 88
#
# Student 2:
# Maths: 3
# Social: 89
# Computer science: 90
# Hindi: 94
#
# Student 3:
# Maths: 96
# Social: 90
# Computer science: 92
# Hindi: 94
#
# ===== STUDENT-WISE ANALYSIS =====
# Student 1 ---> Total: 370.00, Average: 92.50
# Student 2 ---> Total: 276.00, Average: 69.00
# Student 3 ---> Total: 372.00, Average: 93.00
#
# ==== SUBJECT-WISE ANALYSIS ====
#
# Subject: Maths
# Average marks: 64.67
# Highest marks: 96.0
# Lowest marks: 3.0
#
# Subject: Social
# Average marks: 92.33
# Highest marks: 98.0
# Lowest marks: 89.0
#
# Subject: Computer science
# Average marks: 90.33
# Highest marks: 92.0
# Lowest marks: 89.0
#
# Subject: Hindi
# Average marks: 92.00
# Highest marks: 94.0
# Lowest marks: 88.0
# =======OVERALL TOPPER=======
# Topper of the examination: Student3
