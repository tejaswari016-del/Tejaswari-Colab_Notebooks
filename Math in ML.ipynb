# %%
import math

# 1. Simple Equation: Yield Prediction

def predict_yield(rainfall, fertilizer, base_yield=2000):

    rain_coefficient = 10  # kg per mm of rain
    fert_coefficient = 15  # kg per unit of fertilizer

    predicted = base_yield + (rainfall * rain_coefficient) + (fertilizer * fert_coefficient)
    return predicted

print("=== Yield Prediction (Linear Model) ===")
print(f"100mm rain, 50 units fert: {predict_yield(100, 50)} kg/hectare")

# 2. Optimization: Finding best input levels

def profit_function(fertilizer_amount, price_per_kg=20, fert_cost_per_unit=50):

  #Diminishing returns: sqrt function
  yield_increase = 500 * math.sqrt(fertilizer_amount)

  revenue = yield_increase * price_per_kg
  cost = fertilizer_amount * fert_cost_per_unit
  profit = revenue - cost

  return profit

print("\n----Optimization: Best Fertilizer Amount----")
for fert in [10,25,50,100,150]:
    profit = profit_function(fert)
    print(f"Fertilizer: {fert} units --> Profit: Rs.{profit:.0f}")
# Out:
# === Yield Prediction (Linear Model) ===
# 100mm rain, 50 units fert: 3750 kg/hectare
#
# ----Optimization: Best Fertilizer Amount----
# Fertilizer: 10 units --> Profit: Rs.31123
# Fertilizer: 25 units --> Profit: Rs.48750
# Fertilizer: 50 units --> Profit: Rs.68211
# Fertilizer: 100 units --> Profit: Rs.95000
# Fertilizer: 150 units --> Profit: Rs.114974

# %%
import math
import matplotlib.pyplot as plt
import numpy as np

rainfall_list = []
fertilizer_list = []

print("Enter 10 rainfall values(in mm): ")
for i in range(10):
  val = float(input(f"Rainfall{i+1}: "))
  rainfall_list.append(val)

print("\nEnter 10 fertilizer values(in units): ")
for i in range(10):
  val = float(input(f"Fertilizer{i+1}: "))
  fertilizer_list.append(val)

def predict_yield(rainfall, fertilizer, base_yield = 2000):
    rain_coefficient = 10
    fert_coefficient = 15
    predicted = base_yield + (rainfall * rain_coefficient) + (fertilizer * fert_coefficient)
    return predicted

yield_list = [predict_yield(r,f) for r, f in zip(rainfall_list, fertilizer_list)]

def profit_function(fertilizer_amount, price_per_kg=20, fert_cost_per_unit=50):
    yield_increase = math.sqrt(fertilizer_amount)
    revenue = yield_increase * price_per_kg
    cost = fertilizer_amount * fert_cost_per_unit
    profit = revenue - cost
    return profit

profit_list = [profit_function(f) for f in fertilizer_list]

#Display results
print("\n----RESULTS----")
for i in range(10):
    print(f"Rainfall: {rainfall_list [i]} mm,Fertilizer: {fertilizer_list [i]} units --> Yield: {yield_list [i]:.2f} kg/ha, Profit: Rs.{profit_list[i]:.0f}")
# Out:
# Enter 10 rainfall values(in mm):
# Rainfall1: 10
# Rainfall2: 20
# Rainfall3: 30
# Rainfall4: 40
# Rainfall5: 50
# Rainfall6: 60
# Rainfall7: 70
# Rainfall8: 80
# Rainfall9: 90
# Rainfall10: 100
#
# Enter 10 fertilizer values(in units):
# Fertilizer1: 20
# Fertilizer2: 40
# Fertilizer3: 60
# Fertilizer4: 80
# Fertilizer5: 100
# Fertilizer6: 120
# Fertilizer7: 140
# Fertilizer8: 160
# Fertilizer9: 180
# Fertilizer10: 200
#
# ----RESULTS----
# Rainfall: 10.0 mm,Fertilizer: 20.0 units --> Yield: 2400.00 kg/ha, Profit: Rs.-911
# Rainfall: 20.0 mm,Fertilizer: 40.0 units --> Yield: 2800.00 kg/ha, Profit: Rs.-1874
# Rainfall: 30.0 mm,Fertilizer: 60.0 units --> Yield: 3200.00 kg/ha, Profit: Rs.-2845
# Rainfall: 40.0 mm,Fertilizer: 80.0 units --> Yield: 3600.00 kg/ha, Profit: Rs.-3821
# Rainfall: 50.0 mm,Fertilizer: 100.0 units --> Yield: 4000.00 kg/ha, Profit: Rs.-4800
# Rainfall: 60.0 mm,Fertilizer: 120.0 units --> Yield: 4400.00 kg/ha, Profit: Rs.-5781
# Rainfall: 70.0 mm,Fertilizer: 140.0 units --> Yield: 4800.00 kg/ha, Profit: Rs.-6763
# Rainfall: 80.0 mm,Fertilizer: 160.0 units --> Yield: 5200.00 kg/ha, Profit: Rs.-7747
# Rainfall: 90.0 mm,Fertilizer: 180.0 units --> Yield: 5600.00 kg/ha, Profit: Rs.-8732
# Rainfall: 100.0 mm,Fertilizer: 200.0 units --> Yield: 6000.00 kg/ha, Profit: Rs.-9717
